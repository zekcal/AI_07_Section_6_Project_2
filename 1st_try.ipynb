# %% [markdown]
# KoELECTRA의 전이학습을 사용해 진행해보려 했다. 그러나 pytorch에 익숙하지 않았고, 모델의 학습 과정에서 메모리 부족, 모델의 저장 및 불러오기 과정, 예측 함수 실행 등 많은 과정에서 에러가 발생해 최종적으로 프로젝트에 기여한 파일은 아니다.

# %%
import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from tqdm.notebook import tqdm

# %%
from transformers import TFElectraModel
#모델 불러오기
device = torch.device("cuda")
model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-small-v2-discriminator").to(device)
# Out:
# Some weights of the model checkpoint at monologg/koelectra-small-v2-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-small-v2-discriminator and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\zekca\anaconda3\envs\tf15_py37\lib\site-packages\torch\cuda\__init__.py:125: UserWarning:
# NVIDIA GeForce RTX 3060 Laptop GPU with CUDA capability sm_86 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_61 sm_70 sm_75 compute_37.
# If you want to use the NVIDIA GeForce RTX 3060 Laptop GPU GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(incompatible_device_warn.format(device_name, capability, " ".join(arch_list), device_name))

# %%
#클래스 설정
class NSMCDataset(Dataset):
      
  def __init__(self, csv_file):
    # NAN 제거
    self.dataset = pd.read_csv(csv_file, sep='\t').dropna(axis=0) 
    # 중복제거
    self.dataset.drop_duplicates(subset=['document'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-small-v2-discriminator")

    print(self.dataset.describe())
  
  def __len__(self):
    return len(self.dataset)
  
  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 1:3].values
    text = row[0]
    y = row[1]

    inputs = self.tokenizer(
        text, 
        return_tensors='pt',
        truncation=True,
        max_length=256,
        pad_to_max_length=True,
        add_special_tokens=True
        )
    
    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y

# %%
train_dataset = NSMCDataset("ratings_train.txt")
test_dataset = NSMCDataset("ratings_test.txt")
# Out:
#                  id          label
# count  1.461820e+05  146182.000000
# mean   6.779186e+06       0.498283
# std    2.919223e+06       0.499999
# min    3.300000e+01       0.000000
# 25%    4.814832e+06       0.000000
# 50%    7.581160e+06       0.000000
# 75%    9.274760e+06       1.000000
# max    1.027815e+07       1.000000
#                  id         label
# count  4.915700e+04  49157.000000
# mean   6.752945e+06      0.502695
# std    2.937158e+06      0.499998
# min    6.010000e+02      0.000000
# 25%    4.777143e+06      0.000000
# 50%    7.565415e+06      1.000000
# 75%    9.260204e+06      1.000000
# max    1.027809e+07      1.000000

# %%
#캐시 비우는 셀
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
epochs = 5
batch_size = 32

optimizer = AdamW(model.parameters(), lr=1e-5)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
losses = []
accuracies = []

for i in range(epochs):
  total_loss = 0.0
  correct = 0
  total = 0
  batches = 0

  model.train()

  for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
    optimizer.zero_grad()
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
    loss = F.cross_entropy(y_pred, y_batch)
    loss.backward()
    optimizer.step()

    total_loss += loss.item()

    _, predicted = torch.max(y_pred, 1)
    correct += (predicted == y_batch).sum()
    total += len(y_batch)

    batches += 1
    if batches % 100 == 0:
      print("Batch Loss:", total_loss, "Accuracy:", correct.float() / total)
  
  losses.append(total_loss)
  accuracies.append(correct.float() / total)
  print("Train Loss:", total_loss, "Accuracy:", correct.float() / total)
# Out:
#   0%|          | 0/4569 [00:00<?, ?it/s]
# Batch Loss: 962.4680878520012 Accuracy: tensor(0.8608, device='cuda:0')
# Batch Loss: 995.4104513376951 Accuracy: tensor(0.8608, device='cuda:0')
# Batch Loss: 1025.800318568945 Accuracy: tensor(0.8609, device='cuda:0')
# Batch Loss: 1057.1629085540771 Accuracy: tensor(0.8609, device='cuda:0')
# Batch Loss: 1087.8174157738686 Accuracy: tensor(0.8611, device='cuda:0')
# Batch Loss: 1118.3790295124054 Accuracy: tensor(0.8615, device='cuda:0')
# Batch Loss: 1149.65782212466 Accuracy: tensor(0.8618, device='cuda:0')
# Batch Loss: 1180.5516655221581 Accuracy: tensor(0.8619, device='cuda:0')
# Batch Loss: 1211.6589366421103 Accuracy: tensor(0.8620, device='cuda:0')
# Batch Loss: 1243.6523464098573 Accuracy: tensor(0.8619, device='cuda:0')
# Batch Loss: 1274.5066639482975 Accuracy: tensor(0.8619, device='cuda:0')
# Batch Loss: 1305.7463830336928 Accuracy: tensor(0.8620, device='cuda:0')
# Batch Loss: 1336.0818340107799 Accuracy: tensor(0.8620, device='cuda:0')
# Batch Loss: 1367.271838746965 Accuracy: tensor(0.8622, device='cuda:0')
# Batch Loss: 1398.6618312224746 Accuracy: tensor(0.8621, device='cuda:0')
# Batch Loss: 1430.9620266929269 Accuracy: tensor(0.8621, device='cuda:0')
# Train Loss: 1452.8047158643603 Accuracy: tensor(0.8621, device='cuda:0')
#   0%|          | 0/4569 [00:00<?, ?it/s]
# Batch Loss: 28.356926880776882 Accuracy: tensor(0.8744, device='cuda:0')
# Batch Loss: 57.051466040313244 Accuracy: tensor(0.8755, device='cuda:0')
# Batch Loss: 87.81436567753553 Accuracy: tensor(0.8741, device='cuda:0')
# Batch Loss: 116.74185113608837 Accuracy: tensor(0.8759, device='cuda:0')
# Batch Loss: 147.26824869215488 Accuracy: tensor(0.8740, device='cuda:0')
# Batch Loss: 177.57634741067886 Accuracy: tensor(0.8732, device='cuda:0')
# Batch Loss: 206.45984891057014 Accuracy: tensor(0.8729, device='cuda:0')
# Batch Loss: 235.38966889679432 Accuracy: tensor(0.8726, device='cuda:0')
# Batch Loss: 263.90865544974804 Accuracy: tensor(0.8734, device='cuda:0')
# Batch Loss: 292.3339872062206 Accuracy: tensor(0.8737, device='cuda:0')
# Batch Loss: 321.22397039085627 Accuracy: tensor(0.8734, device='cuda:0')
# Batch Loss: 350.10021747648716 Accuracy: tensor(0.8735, device='cuda:0')
# Batch Loss: 379.6919996291399 Accuracy: tensor(0.8737, device='cuda:0')
# Batch Loss: 408.67237758636475 Accuracy: tensor(0.8740, device='cuda:0')
# Batch Loss: 436.895819529891 Accuracy: tensor(0.8743, device='cuda:0')
# Batch Loss: 462.5788397192955 Accuracy: tensor(0.8757, device='cuda:0')
# Batch Loss: 491.6029478088021 Accuracy: tensor(0.8755, device='cuda:0')
# Batch Loss: 519.7157411947846 Accuracy: tensor(0.8757, device='cuda:0')
# Batch Loss: 549.3990979641676 Accuracy: tensor(0.8755, device='cuda:0')
# Batch Loss: 579.6634218841791 Accuracy: tensor(0.8750, device='cuda:0')
# Batch Loss: 608.3183002248406 Accuracy: tensor(0.8751, device='cuda:0')
# Batch Loss: 638.4585681855679 Accuracy: tensor(0.8749, device='cuda:0')
# Batch Loss: 666.9573403820395 Accuracy: tensor(0.8753, device='cuda:0')
# Batch Loss: 696.3360435962677 Accuracy: tensor(0.8753, device='cuda:0')
# Batch Loss: 723.9831931591034 Accuracy: tensor(0.8754, device='cuda:0')
# Batch Loss: 753.5029176548123 Accuracy: tensor(0.8754, device='cuda:0')
# Batch Loss: 782.0919208452106 Accuracy: tensor(0.8754, device='cuda:0')
# Batch Loss: 810.8559592366219 Accuracy: tensor(0.8754, device='cuda:0')
# Batch Loss: 838.6086804121733 Accuracy: tensor(0.8758, device='cuda:0')
# Batch Loss: 866.4572646021843 Accuracy: tensor(0.8759, device='cuda:0')
# Batch Loss: 896.381251424551 Accuracy: tensor(0.8757, device='cuda:0')
# Batch Loss: 923.930063188076 Accuracy: tensor(0.8759, device='cuda:0')
# Batch Loss: 952.3064628690481 Accuracy: tensor(0.8761, device='cuda:0')
# Batch Loss: 980.6883747428656 Accuracy: tensor(0.8763, device='cuda:0')
# Batch Loss: 1009.7681904733181 Accuracy: tensor(0.8763, device='cuda:0')
# Batch Loss: 1039.4723057374358 Accuracy: tensor(0.8762, device='cuda:0')
# Batch Loss: 1069.2391943782568 Accuracy: tensor(0.8761, device='cuda:0')
# Batch Loss: 1098.0732749849558 Accuracy: tensor(0.8762, device='cuda:0')
# Batch Loss: 1126.7025261893868 Accuracy: tensor(0.8763, device='cuda:0')
# Batch Loss: 1155.4841320365667 Accuracy: tensor(0.8763, device='cuda:0')
# Batch Loss: 1184.6993157044053 Accuracy: tensor(0.8762, device='cuda:0')
# Batch Loss: 1213.1719032153487 Accuracy: tensor(0.8762, device='cuda:0')
# Batch Loss: 1243.595706231892 Accuracy: tensor(0.8761, device='cuda:0')
# Batch Loss: 1271.8494411706924 Accuracy: tensor(0.8761, device='cuda:0')
# Batch Loss: 1300.0511380061507 Accuracy: tensor(0.8763, device='cuda:0')
# Train Loss: 1318.4067158661783 Accuracy: tensor(0.8766, device='cuda:0')
#   0%|          | 0/4569 [00:00<?, ?it/s]
# Batch Loss: 28.24914515018463 Accuracy: tensor(0.8847, device='cuda:0')
# Batch Loss: 55.38689959794283 Accuracy: tensor(0.8861, device='cuda:0')
# Batch Loss: 82.10857161134481 Accuracy: tensor(0.8863, device='cuda:0')
# Batch Loss: 109.42385046929121 Accuracy: tensor(0.8878, device='cuda:0')
# Batch Loss: 136.06794829666615 Accuracy: tensor(0.8879, device='cuda:0')
# Batch Loss: 163.1275979578495 Accuracy: tensor(0.8884, device='cuda:0')
# Batch Loss: 190.49173633754253 Accuracy: tensor(0.8876, device='cuda:0')
# Batch Loss: 218.47568356990814 Accuracy: tensor(0.8871, device='cuda:0')
# Batch Loss: 244.60915421694517 Accuracy: tensor(0.8874, device='cuda:0')
# Batch Loss: 269.7690526768565 Accuracy: tensor(0.8879, device='cuda:0')
# Batch Loss: 295.17988200485706 Accuracy: tensor(0.8882, device='cuda:0')
# Batch Loss: 322.38947205245495 Accuracy: tensor(0.8877, device='cuda:0')
# Batch Loss: 348.7889391183853 Accuracy: tensor(0.8875, device='cuda:0')
# Batch Loss: 376.89732099324465 Accuracy: tensor(0.8871, device='cuda:0')
# Batch Loss: 405.18064756691456 Accuracy: tensor(0.8869, device='cuda:0')
# Batch Loss: 434.1160132586956 Accuracy: tensor(0.8861, device='cuda:0')
# Batch Loss: 458.874168805778 Accuracy: tensor(0.8867, device='cuda:0')
# Batch Loss: 485.7046075537801 Accuracy: tensor(0.8868, device='cuda:0')
# Batch Loss: 512.5622857138515 Accuracy: tensor(0.8865, device='cuda:0')
# Batch Loss: 540.4580717161298 Accuracy: tensor(0.8861, device='cuda:0')
# Batch Loss: 566.3900936990976 Accuracy: tensor(0.8864, device='cuda:0')
# Batch Loss: 592.3444972336292 Accuracy: tensor(0.8864, device='cuda:0')
# Batch Loss: 621.0218698009849 Accuracy: tensor(0.8859, device='cuda:0')
# Batch Loss: 648.7106701284647 Accuracy: tensor(0.8856, device='cuda:0')
# Batch Loss: 675.1445650681853 Accuracy: tensor(0.8855, device='cuda:0')
# Batch Loss: 701.4705909118056 Accuracy: tensor(0.8857, device='cuda:0')
# Batch Loss: 726.2374598607421 Accuracy: tensor(0.8860, device='cuda:0')
# Batch Loss: 752.957880936563 Accuracy: tensor(0.8858, device='cuda:0')
# Batch Loss: 781.4292533323169 Accuracy: tensor(0.8856, device='cuda:0')
# Batch Loss: 808.6759650558233 Accuracy: tensor(0.8855, device='cuda:0')
# Batch Loss: 835.1722708493471 Accuracy: tensor(0.8855, device='cuda:0')
# Batch Loss: 862.274746388197 Accuracy: tensor(0.8854, device='cuda:0')
# Batch Loss: 889.7262295633554 Accuracy: tensor(0.8853, device='cuda:0')
# Batch Loss: 915.1848621815443 Accuracy: tensor(0.8857, device='cuda:0')
# Batch Loss: 941.0358867049217 Accuracy: tensor(0.8860, device='cuda:0')
# Batch Loss: 967.4089308306575 Accuracy: tensor(0.8859, device='cuda:0')
# Batch Loss: 993.4559547901154 Accuracy: tensor(0.8860, device='cuda:0')
# Batch Loss: 1019.8870343267918 Accuracy: tensor(0.8861, device='cuda:0')
# Batch Loss: 1045.5591442734003 Accuracy: tensor(0.8862, device='cuda:0')
# Batch Loss: 1072.6754429787397 Accuracy: tensor(0.8862, device='cuda:0')
# Batch Loss: 1098.1922266483307 Accuracy: tensor(0.8864, device='cuda:0')
# Batch Loss: 1125.8437751755118 Accuracy: tensor(0.8863, device='cuda:0')
# Batch Loss: 1151.9296956062317 Accuracy: tensor(0.8864, device='cuda:0')
# Batch Loss: 1176.5656522884965 Accuracy: tensor(0.8867, device='cuda:0')
# Batch Loss: 1204.7697384133935 Accuracy: tensor(0.8865, device='cuda:0')
# Train Loss: 1224.1696892157197 Accuracy: tensor(0.8865, device='cuda:0')
#   0%|          | 0/4569 [00:00<?, ?it/s]
# Batch Loss: 25.547676615417004 Accuracy: tensor(0.8822, device='cuda:0')
# Batch Loss: 49.990578323602676 Accuracy: tensor(0.8897, device='cuda:0')
# Batch Loss: 74.73963459581137 Accuracy: tensor(0.8908, device='cuda:0')
# Batch Loss: 101.15627886354923 Accuracy: tensor(0.8921, device='cuda:0')
# Batch Loss: 125.94734793156385 Accuracy: tensor(0.8938, device='cuda:0')
# Batch Loss: 150.28235943615437 Accuracy: tensor(0.8942, device='cuda:0')
# Batch Loss: 174.80936724692583 Accuracy: tensor(0.8945, device='cuda:0')
# Batch Loss: 198.94953168183565 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 223.96615609899163 Accuracy: tensor(0.8958, device='cuda:0')
# Batch Loss: 248.35097406432033 Accuracy: tensor(0.8963, device='cuda:0')
# Batch Loss: 271.11639020219445 Accuracy: tensor(0.8977, device='cuda:0')
# Batch Loss: 295.3084304444492 Accuracy: tensor(0.8978, device='cuda:0')
# Batch Loss: 319.41107895597816 Accuracy: tensor(0.8975, device='cuda:0')
# Batch Loss: 343.9091587215662 Accuracy: tensor(0.8977, device='cuda:0')
# Batch Loss: 369.76763239502907 Accuracy: tensor(0.8975, device='cuda:0')
# Batch Loss: 394.357485704124 Accuracy: tensor(0.8976, device='cuda:0')
# Batch Loss: 418.02134224027395 Accuracy: tensor(0.8979, device='cuda:0')
# Batch Loss: 442.9177782163024 Accuracy: tensor(0.8978, device='cuda:0')
# Batch Loss: 469.6472328566015 Accuracy: tensor(0.8972, device='cuda:0')
# Batch Loss: 494.07395105436444 Accuracy: tensor(0.8972, device='cuda:0')
# Batch Loss: 518.7320563010871 Accuracy: tensor(0.8970, device='cuda:0')
# Batch Loss: 543.7390652410686 Accuracy: tensor(0.8968, device='cuda:0')
# Batch Loss: 568.8884181044996 Accuracy: tensor(0.8970, device='cuda:0')
# Batch Loss: 595.5414139442146 Accuracy: tensor(0.8967, device='cuda:0')
# Batch Loss: 619.9385742433369 Accuracy: tensor(0.8968, device='cuda:0')
# Batch Loss: 645.7455394677818 Accuracy: tensor(0.8965, device='cuda:0')
# Batch Loss: 669.9839031100273 Accuracy: tensor(0.8968, device='cuda:0')
# Batch Loss: 696.0286621153355 Accuracy: tensor(0.8965, device='cuda:0')
# Batch Loss: 721.7145950235426 Accuracy: tensor(0.8964, device='cuda:0')
# Batch Loss: 746.3915572576225 Accuracy: tensor(0.8965, device='cuda:0')
# Batch Loss: 770.5611889250576 Accuracy: tensor(0.8967, device='cuda:0')
# Batch Loss: 796.097359444946 Accuracy: tensor(0.8966, device='cuda:0')
# Batch Loss: 823.2908215112984 Accuracy: tensor(0.8961, device='cuda:0')
# Batch Loss: 849.8673726730049 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 874.0605996213853 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 897.4881936050951 Accuracy: tensor(0.8959, device='cuda:0')
# Batch Loss: 923.2684712223709 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 947.1890826933086 Accuracy: tensor(0.8959, device='cuda:0')
# Batch Loss: 973.2656641490757 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 998.4669713489711 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 1023.6124450005591 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 1048.055010508746 Accuracy: tensor(0.8957, device='cuda:0')
# Batch Loss: 1071.6675158031285 Accuracy: tensor(0.8959, device='cuda:0')
# Batch Loss: 1096.542407732457 Accuracy: tensor(0.8960, device='cuda:0')
# Batch Loss: 1121.7951464243233 Accuracy: tensor(0.8959, device='cuda:0')
# Train Loss: 1139.8345448412 Accuracy: tensor(0.8958, device='cuda:0')

# %%
losses, accuracies
# Out:
# ([1827.4496524631977,
#   1452.8047158643603,
#   1318.4067158661783,
#   1224.1696892157197,
#   1139.8345448412],
#  [tensor(0.8206, device='cuda:0'),
#   tensor(0.8621, device='cuda:0'),
#   tensor(0.8766, device='cuda:0'),
#   tensor(0.8865, device='cuda:0'),
#   tensor(0.8958, device='cuda:0')])

# %%
# 모델 저장하기
torch.save(model.state_dict(), "model.pt")

# %%
#테스트셋 정확도 평가, 메모리 부족으로 실행은 하지 않음
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
  y_batch = y_batch.to(device)
  y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
  _, predicted = torch.max(y_pred, 1)
  test_correct += (predicted == y_batch).sum()
  test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)

# %%
#모델 불러오기, 어떻게....?
model = ElectraForSequenceClassification()
model.load_state_dict(torch.load('model.pt'))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14104\119839266.py in <module>
#       1 #모델 불러오기
# ----> 2 model = ElectraForSequenceClassification()
#       3 model.load_state_dict(torch.load('model.pt'))
#       4 model.eval()
#
# TypeError: __init__() missing 1 required positional argument: 'config'

# %%
#예측 함수
tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-small-v2-discriminator")
max_input_length = 256
init_token = tokenizer.cls_token
eos_token = tokenizer.sep_token
pad_token = tokenizer.pad_token
unk_token = tokenizer.unk_token
init_token_idx = tokenizer.convert_tokens_to_ids(init_token)
eos_token_idx = tokenizer.convert_tokens_to_ids(eos_token)
pad_token_idx = tokenizer.convert_tokens_to_ids(pad_token)
unk_token_idx = tokenizer.convert_tokens_to_ids(unk_token)

def predict_sentiment(model, tokenizer, sentence):
    model.eval()
    tokens = tokenizer.tokenize(sentence)
    tokens = tokens[:max_input_length-2]
    indexed = [init_token_idx] + tokenizer.convert_tokens_to_ids(tokens) + [eos_token_idx]
    tensor = torch.LongTensor(indexed).to(device)
    tensor = tensor.unsqueeze(0)
    prediction = torch.sigmoid(model(tensor))
    return prediction.item()

# %%
predict_sentiment(model, tokenizer, "이 영화 진짜 재밌었다!!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11568\660868487.py in <module>
# ----> 1 predict_sentiment(model, tokenizer, "이 영화 진짜 재밌었다!!")
#
# ~\AppData\Local\Temp\ipykernel_11568\1900349212.py in predict_sentiment(model, tokenizer, sentence)
#      18     tensor = torch.LongTensor(indexed).to(device)
#      19     tensor = tensor.unsqueeze(0)
# ---> 20     prediction = torch.sigmoid(model(tensor))
#      21     return prediction.item()
#
# TypeError: sigmoid(): argument 'input' (position 1) must be Tensor, not SequenceClassifierOutput
